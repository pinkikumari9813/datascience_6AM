# %%
from google import genai
import os

# %%
print(os.environ.get('GEMINI_API_KEY'))
# Out:
# AIzaSyCNervTIlWrVhI31wATWIVcyPzCso0AbNo

# %%
client = genai.Client(api_key = os.getenv('GEMINI_API_KEY'))

# %%
def generate_prompt(text):
    response = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents=text
    )
    return response.text

# %%
generate_prompt('When was last time you were trained?')
# Out:
# 'My knowledge cutoff—the point at which the vast majority of my training data ends—is **early 2024**. \n\nHowever, because I am a large language model trained by Google, I am periodically updated, and I can also access information in real-time through Google Search to provide you with the most current news and facts.'
